# %%
import valency_anndata as val

# %%
adata = val.datasets.polis.load("https://pol.is/report/r2dfw8eambusb8buvecjt")

# %%
val.tools.recipe_polis(adata)

# %%
from pacmap import PaCMAP

X = adata.layers["X_masked_imputed_mean"]

print(X)

estimator = PaCMAP(n_components=2)
estimator.fit_transform(X)
